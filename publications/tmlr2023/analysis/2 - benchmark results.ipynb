# %%
import sys
import matplotlib.pyplot as plt

sys.path.append("..")  # make whole paper related package accessible

# %%
from experiments.benchmark.result_storage import ResultStorage

# %%
with open("../experiments/results/61_0_0.json", "r") as f:
    result_storage = ResultStorage.unserialize(f)

# %%
fig, ax = plt.subplots()
for a in result_storage._approach_names:
    errors = result_storage.get_errors_from_approach_for_checkpoint(approach_name=a, t=100)
    ax.plot(errors.index, errors["E[Z_nt]"], label=a)
ax.legend()
plt.show()
